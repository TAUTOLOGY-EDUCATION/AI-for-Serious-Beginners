# %% [markdown]
# # 1. Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import (
    r2_score, 
    mean_squared_error, 
    mean_absolute_error, 
    mean_absolute_percentage_error
)

import warnings
warnings.filterwarnings('ignore')

np.random.seed(12345)

# %% [markdown]
# # 2. Read Data

# %%
data = pd.read_csv('eurusd_dataset.csv')

data
# Out:
#               Date  Open_0  STD5_Open_0  RSI14_Open_0   ATR14_0  High_0  \
# 0     Jan 22, 2010  1.4080     0.012424     37.911025  0.014679  1.4182
# 1     Jan 25, 2010  1.4161     0.011589     43.082121  0.014466  1.4199
# 2     Jan 26, 2010  1.4150     0.007287     42.563679  0.013940  1.4181
# 3     Jan 27, 2010  1.4075     0.003534     39.108088  0.013937  1.4098
# 4     Jan 28, 2010  1.4021     0.005187     36.792007  0.013684  1.4053
# ...            ...     ...          ...           ...       ...     ...
# 3050  Oct 01, 2021  1.1582     0.005662     26.399348  0.005308  1.1608
# 3051  Oct 04, 2021  1.1593     0.004898     28.744404  0.005250  1.1641
# 3052  Oct 05, 2021  1.1623     0.003639     34.841921  0.005261  1.1623
# 3053  Oct 06, 2021  1.1603     0.001360     32.825248  0.005192  1.1605
# 3054  Oct 07, 2021  1.1556     0.002226     28.631267  0.005364  1.1573
#
#        Low_0
# 0     1.4065
# 1     1.4128
# 2     1.4042
# 3     1.3994
# 4     1.3936
# ...      ...
# 3050  1.1563
# 3051  1.1587
# 3052  1.1580
# 3053  1.1529
# 3054  1.1547
#
# [3055 rows x 7 columns]

# %%
data.drop(['Date', 'Low_0'], axis=1, inplace=True)

data
# Out:
#       Open_0  STD5_Open_0  RSI14_Open_0   ATR14_0  High_0
# 0     1.4080     0.012424     37.911025  0.014679  1.4182
# 1     1.4161     0.011589     43.082121  0.014466  1.4199
# 2     1.4150     0.007287     42.563679  0.013940  1.4181
# 3     1.4075     0.003534     39.108088  0.013937  1.4098
# 4     1.4021     0.005187     36.792007  0.013684  1.4053
# ...      ...          ...           ...       ...     ...
# 3050  1.1582     0.005662     26.399348  0.005308  1.1608
# 3051  1.1593     0.004898     28.744404  0.005250  1.1641
# 3052  1.1623     0.003639     34.841921  0.005261  1.1623
# 3053  1.1603     0.001360     32.825248  0.005192  1.1605
# 3054  1.1556     0.002226     28.631267  0.005364  1.1573
#
# [3055 rows x 5 columns]

# %% [markdown]
# # 3. Clean Data

# %% [markdown]
# ## 3.1. Handle Missing Values

# %% [markdown]
# ### 3.1.1. Check Missing Values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3055 entries, 0 to 3054
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open_0        3055 non-null   float64
#  1   STD5_Open_0   3055 non-null   float64
#  2   RSI14_Open_0  3055 non-null   float64
#  3   ATR14_0       3055 non-null   float64
#  4   High_0        3055 non-null   float64
# dtypes: float64(5)
# memory usage: 119.5 KB

# %% [markdown]
# ### 3.1.2. Remove Missing Values (Listwise Deletion)

# %%
# no NaN to remove
# data.dropna(axis=0, inplace=True)

# %% [markdown]
# ## 3.2. Handle Outliers

# %% [markdown]
# ### 3.2.1. Check Outliers

# %%
data.describe()
# Out:
#             Open_0  STD5_Open_0  RSI14_Open_0      ATR14_0       High_0
# count  3055.000000  3055.000000   3055.000000  3055.000000  3055.000000
# mean      1.219992     0.005054     49.314276     0.010004     1.224946
# std       0.107676     0.003171     11.638349     0.003498     0.108243
# min       1.038900     0.000331     14.375997     0.004142     1.041900
# 25%       1.123650     0.002815     41.078958     0.007517     1.128500
# 50%       1.192600     0.004194     49.221307     0.009233     1.196700
# 75%       1.317550     0.006511     57.361952     0.012088     1.322200
# max       1.482900     0.025305     81.560471     0.020626     1.494200

# %% [markdown]
# ### 3.2.2. Remove Outliers

# %%
# no outlier to remove

# %% [markdown]
# # 4. Split Dataset into Training & Test Sets

# %%
target_name = 'High_0'
feature_name = list(data.columns.drop(target_name))

# %%
X = data[feature_name]
y = data[target_name]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, shuffle=False)

# %% [markdown]
# # ### 5. Data Preparation

# %% [markdown]
# # 6. Model Creation

# %% [markdown]
# ## 6.1. Setting Parameters

# %%
reg = LinearRegression()

# %% [markdown]
# ## 6.2. Train Model

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## 6.3. Model's Weight & Bias

# %%
reg.coef_
# Out:
# array([ 9.98433922e-01, -7.83211493e-03, -4.27231535e-06,  4.56585479e-01])

# %%
reg.intercept_
# Out:
# 0.002577783084327878

# %% [markdown]
# # 7. Prediction

# %% [markdown]
# ## 7.1. Training Set

# %%
y_pred_train = reg.predict(X_train)

# %% [markdown]
# ## 7.2. Test Set

# %%
y_pred_test = reg.predict(X_test)

# %% [markdown]
# # 8. Model Evaluation

# %% [markdown]
# ## 8.1. Training Set

# %% [markdown]
# ### 8.1.1. Scoring

# %%
print('r2_score =\t\t\t', r2_score(y_train, y_pred_train))
print('mean_squared_error =\t\t', mean_squared_error(y_train, y_pred_train))
print('mean_absolute_error =\t\t', mean_absolute_error(y_train, y_pred_train))
print('mean_absolute_percentage_error =', mean_absolute_percentage_error(y_train, y_pred_train))
# Out:
# r2_score =			 0.9984417345053788
# mean_squared_error =		 1.968659991142055e-05
# mean_absolute_error =		 0.0032338102962371465
# mean_absolute_percentage_error = 0.0026064669165995003

# %% [markdown]
# ### 8.1.2. Scatter Plot between Predicted & Actual Values

# %%
plt.scatter(y_pred_train, y_train)

plt.plot(y_pred_train, y_pred_train, color='red')

plt.title('Scatter Plot between Predicted & Actual Values')
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Out:
# Text(0, 0.5, 'Actual')

# %% [markdown]
# ## 8.2. Test Set

# %% [markdown]
# ### 8.2.1. Scoring

# %%
print('r2_score =\t\t\t', r2_score(y_test, y_pred_test))
print('mean_squared_error =\t\t', mean_squared_error(y_test, y_pred_test))
print('mean_absolute_error =\t\t', mean_absolute_error(y_test, y_pred_test))
print('mean_absolute_percentage_error =', mean_absolute_percentage_error(y_test, y_pred_test))
# Out:
# r2_score =			 0.9958540336763514
# mean_squared_error =		 8.358328830305404e-06
# mean_absolute_error =		 0.0022010006124765498
# mean_absolute_percentage_error = 0.0019120336493832764

# %% [markdown]
# ### 8.2.2. Scatter Plot between Predicted & Actual Values

# %%
plt.scatter(y_pred_test, y_test)

plt.plot(y_pred_test, y_pred_test, color='red')

plt.title('Scatter Plot between Predicted & Actual Values')
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Out:
# Text(0, 0.5, 'Actual')

# %% [markdown]
# ### 8.2.3. Plot between Predicted & Actual Values (Zoom)

# %%
y_test = y_test.to_numpy()

# %%
step = 10

import math
n_rows = int(math.ceil(len(y_test)/(2*step)))

fig = plt.figure(figsize=(18, 6*n_rows))

for i in range(0, len(y_test), step):
    start = i
    stop = min(i + step, len(y_test))
    plt.subplot(n_rows, 2, i//step + 1)
    plt.plot(y_test[start:stop], label=f'Actual High {start}-{stop-1}')
    plt.plot(y_pred_test[start:stop], '*', label=f'Predicted High {start}-{stop-1}')
    plt.legend()

# %% [markdown]
# # 9. Save Model

# %%
import pickle

# %%
pickle.dump((reg, feature_name), open('eurusd_model.pickle', 'wb'))
